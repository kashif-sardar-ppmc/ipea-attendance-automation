# %%
import pandas as pd

# %%
df=pd.read_json('att.json')
df
# Out:
#      success  count                                               data
# 0       True    750  {'employee_id': 852, 'name': 'Doctor Jehanzeb ...
# 1       True    750  {'employee_id': 934, 'name': 'Mr. Abu Baker Ma...
# 2       True    750  {'employee_id': 1024, 'name': 'Mr. Ahmad Zubai...
# 3       True    750  {'employee_id': 960, 'name': 'Mr. Ali Yousaf K...
# 4       True    750  {'employee_id': 870, 'name': 'Mr. Aqib Nawaz K...
# ..       ...    ...                                                ...
# 745     True    750  {'employee_id': 1026, 'name': 'Mr. Syed Mujtab...
# 746     True    750  {'employee_id': 855, 'name': 'Mr. Ubaid Ullah ...
# 747     True    750  {'employee_id': 1037, 'name': 'Ms. Mahnoor Sal...
# 748     True    750  {'employee_id': 1038, 'name': 'Ms. Nawal', 'de...
# 749     True    750  {'employee_id': 945, 'name': 'Ms. Sumbal Bibi'...
#
# [750 rows x 3 columns]
